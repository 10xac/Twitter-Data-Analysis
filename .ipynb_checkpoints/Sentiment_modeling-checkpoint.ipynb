# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

import numpy as np # linear algebra
from scipy.stats import uniform
from scipy.sparse import csr_matrix

# %matplotlib inline

# %%
# Import the data
tweet_df = pd.read_csv("clean_preprocessed.csv")
tweet_df.columns
tweet_df = tweet_df.rename(columns={'preproc_text':'clean_text'})
cleanTweet = tweet_df.copy()[["clean_text","polarity"]]

# %%
# Define the sentiment carrying in the text
def text_category(tweet_polarity):
    '''A function to return the sentiment carried by a tweet text'''
    if tweet_polarity>0:
        return "positive"
    elif tweet_polarity<0:
        return "negative"
    else:
        return "neutral"

# %%
cleanTweet["score"] = cleanTweet["polarity"].apply(text_category)
score_sent = cleanTweet["score"].value_counts()
score_sent
# Out:
# neutral     6932
# positive    5722
# negative    2428
# Name: score, dtype: int64

# %%
plt.bar(score_sent.index,score_sent.values)
plt.show()

# %%
fig,ax = plt.subplots(1,2)
ax[0].bar(score_sent.index,score_sent.values)
ax[1].pie(score_sent,labels=['neutral','positive','negative'])
plt.show()

# %%
# Extract the positive and negative
cleanTweet = cleanTweet[cleanTweet["score"]!="neutral"]
cleanTweet["score"].value_counts()
# Out:
# positive    5722
# negative    2428
# Name: score, dtype: int64

# %%
# Re-index the frame
cleanTweet = cleanTweet.reset_index(drop=True)
cleanTweet
# Out:
#                                              clean_text  polarity     score
# 0     rt @northstarcharts: the -year yield is tellin...  0.160000  positive
# 1     rt @michaelaarouet: german y mortgage rate wen...  0.150000  positive
# 2     rt @biancoresearch: rates rise until something... -0.400000  negative
# 3     rt @lanceroberts: buying opportunities like th... -0.100000  negative
# 4     rt @macroalf: welcome to september .\n\nbond m...  0.400000  positive
# ...                                                 ...       ...       ...
# 8145  rt @ferozkhaninc: in #telangana rapes, murders...  0.095455  positive
# 8146  rt @ozamizcps: pssg gedson castañeros, mobile ...  0.100000  positive
# 8147  rt @salt_project_os: free yourself from writin...  0.400000  positive
# 8148  rt @pbhushan: thank you @bajpayeemanoj for thi...  0.850000  positive
# 8149  rt @tejjinc: . peace yatra by late sunil dutt ... -0.300000  negative
#
# [8150 rows x 3 columns]

# %%
# Create a function to encode the sentiment
def encode_sentiment(sentiment):
    '''Encode the sentiment. 1 if positive, 0 otherwise'''
    if sentiment=="positive":
        return 1
    else: return 0

# %%
cleanTweet['scoremap'] = cleanTweet['score'].apply(encode_sentiment)
cleanTweet['scoremap'].describe()
# Out:
# count    8150.000000
# mean        0.702086
# std         0.457370
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: scoremap, dtype: float64

# %%
# Create features and target variable
(X,y) = (cleanTweet['clean_text'],cleanTweet['scoremap'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
# Create the trigram vectorize
trigram_vectorizer = CountVectorizer(ngram_range=(1, 3))
trigram_vectorizer.fit(X_train.values)
# Out:
# CountVectorizer(ngram_range=(1, 3))

# %%
trigram_vectorizer.vocabulary_
# Out:
# {'whyteleafeeagle': 172843,
#  'sorry': 138592,
#  'but': 22595,
#  'he': 63967,
#  'going': 58834,
#  'to': 156276,
#  'trip': 161710,
#  'himself': 65911,
#  'up': 164525,
#  'should': 135505,
#  'have': 63085,
#  'used': 165568,
#  'an': 5970,
#  'extendable': 48676,
#  'lead': 83954,
#  'whyteleafeeagle sorry': 172844,
#  'sorry but': 138595,
#  'but he': 22706,
#  'he going': 64068,
#  'going to': 58899,
#  'to trip': 159263,
#  'trip himself': 161715,
#  'himself up': 65917,
#  'up should': 164710,
#  'should have': 135557,
#  'have used': 63699,
#  'used an': 165571,
#  'an extendable': 6166,
#  'extendable lead': 48677,
#  'whyteleafeeagle sorry but': 172845,
#  'sorry but he': 138596,
#  'but he going': 22710,
#  'he going to': 64070,
#  'going to trip': 58936,
#  'to trip himself': 159264,
#  'trip himself up': 161716,
#  'himself up should': 65918,
#  'up should have': 164711,
#  'should have used': 135563,
#  'have used an': 63700,
#  'used an extendable': 165572,
#  'an extendable lead': 6167,
#  'leftists': 84511,
#  'anti': 9301,
#  'police': 115320,
#  'policies': 115370,
#  'led': 84387,
#  'startling': 140296,
#  'number': 102943,
#  'of': 103531,
#  'black': 19373,
#  'latino': 83599,
#  'crime': 35846,
#  'victims': 166835,
#  'co': 28487,
#  'kwbkkyvlw': 82689,
#  'leftists anti': 84512,
#  'anti police': 9322,
#  'police policies': 115352,
#  'policies have': 115381,
#  'have led': 63400,
#  'led to': 84395,
#  'to startling': 158902,
#  'startling number': 140299,
#  'number of': 102952,
#  'of black': 103735,
#  'black latino': 19401,
#  'latino crime': 83600,
#  'crime victims': 35855,
#  'victims co': 166841,
#  'co kwbkkyvlw': 29888,
#  'leftists anti police': 84513,
#  'anti police policies': 9323,
#  'police policies have': 115353,
#  'policies have led': 115382,
#  'have led to': 63401,
#  'led to startling': 84397,
#  'to startling number': 158903,
#  'startling number of': 140300,
#  'number of black': 102955,
#  'of black latino': 103736,
#  'black latino crime': 19402,
#  'latino crime victims': 83601,
#  'crime victims co': 35856,
#  'victims co kwbkkyvlw': 166842,
#  'oregongovbrown': 109376,
#  'lamresearch': 83031,
#  'adi_news': 1755,
#  'these': 153265,
#  'corporations': 34481,
#  'are': 10300,
#  'require': 123295,
#  'educated': 44822,
#  'and': 6481,
#  'intelligent': 73656,
#  'people': 112927,
#  'whic': 171940,
#  'kcnpzgkmq': 81048,
#  'oregongovbrown lamresearch': 109379,
#  'lamresearch adi_news': 83032,
#  'adi_news these': 1756,
#  'these corporations': 153297,
#  'corporations are': 34482,
#  'are going': 10622,
#  'to require': 158574,
#  'require educated': 123300,
#  'educated and': 44823,
#  'and intelligent': 7467,
#  'intelligent people': 73661,
#  'people whic': 113227,
#  'whic co': 171941,
#  'co kcnpzgkmq': 29781,
#  'oregongovbrown lamresearch adi_news': 109380,
#  'lamresearch adi_news these': 83033,
#  'adi_news these corporations': 1757,
#  'these corporations are': 153298,
#  'corporations are going': 34484,
#  'are going to': 10625,
#  'going to require': 58928,
#  'to require educated': 158575,
#  'require educated and': 123301,
#  'educated and intelligent': 44824,
#  'and intelligent people': 7468,
#  'intelligent people whic': 73663,
#  'people whic co': 113228,
#  'whic co kcnpzgkmq': 171942,
#  'two': 162857,
#  'years': 177077,
#  'ago': 2813,
#  'was': 168429,
#  'sitting': 136670,
#  'in': 69837,
#  'parking': 111813,
#  'lot': 87713,
#  'watching': 169083,
#  'master': 91471,
#  'walking': 167930,
#  'six': 136713,
#  'feet': 50413,
#  'apart': 9709,
#  'good': 59184,
#  'times': 155991,
#  'covid': 35225,
#  'cdc': 25702,
#  'ongbpwgmxd': 108375,
#  'two years': 162984,
#  'years ago': 177078,
#  'ago was': 2852,
#  'was sitting': 168795,
#  'sitting in': 136675,
#  'in parking': 71011,
#  'parking lot': 111816,
#  'lot watching': 87745,
#  'watching people': 169099,
#  'people master': 113096,
#  'master walking': 91473,
#  'walking six': 167935,
#  'six feet': 136716,
#  'feet apart': 50414,
#  'apart good': 9719,
#  'good times': 59463,
#  'times covid': 156011,
#  'covid cdc': 35255,
#  'cdc co': 25703,
#  'co ongbpwgmxd': 30370,
#  'two years ago': 162985,
#  'years ago was': 177086,
#  'ago was sitting': 2853,
#  'was sitting in': 168796,
#  'sitting in parking': 136676,
#  'in parking lot': 71012,
#  'parking lot watching': 111817,
#  'lot watching people': 87746,
#  'watching people master': 169100,
#  'people master walking': 113097,
#  'master walking six': 91474,
#  'walking six feet': 167936,
#  'six feet apart': 136717,
#  'feet apart good': 50415,
#  'apart good times': 9720,
#  'good times covid': 59464,
#  'times covid cdc': 156012,
#  'covid cdc co': 35256,
#  'cdc co ongbpwgmxd': 25704,
#  'growth': 61049,
#  'moral': 95368,
#  'purity': 119004,
#  'is': 74696,
#  'the': 147132,
#  'ultimate': 163622,
#  'indication': 72612,
#  'deep': 38584,
#  'devotion': 39966,
#  'jesus': 78999,
#  'christ': 27425,
#  'genuine': 57403,
#  'interest': 73708,
#  'wo': 174860,
#  'tbvixekfl': 144636,
#  'growth in': 61067,
#  'in moral': 70838,
#  'moral purity': 95375,
#  'purity is': 119005,
#  'is the': 76214,
#  'the ultimate': 151729,
#  'ultimate indication': 163623,
#  'indication of': 72613,
#  'of deep': 104063,
#  'deep devotion': 38588,
#  'devotion to': 39967,
#  'to jesus': 157792,
#  'jesus christ': 79002,
#  'christ genuine': 27430,
#  'genuine interest': 57406,
#  'interest in': 73713,
#  'in and': 69922,
#  'and wo': 8702,
#  'wo co': 174861,
#  'co tbvixekfl': 30973,
#  'growth in moral': 61070,
#  'in moral purity': 70839,
#  'moral purity is': 95376,
#  'purity is the': 119006,
#  'is the ultimate': 76293,
#  'the ultimate indication': 151730,
#  'ultimate indication of': 163624,
#  'indication of deep': 72614,
#  'of deep devotion': 104065,
#  'deep devotion to': 38589,
#  'devotion to jesus': 39968,
#  'to jesus christ': 157793,
#  'jesus christ genuine': 79003,
#  'christ genuine interest': 27431,
#  'genuine interest in': 57407,
#  'interest in and': 73714,
#  'in and wo': 69927,
#  'and wo co': 8703,
#  'wo co tbvixekfl': 174864,
#  'see': 133356,
#  'why': 172628,
#  'unitedrentals': 164165,
#  'uri': 165121,
#  'trend': 161498,
#  'vantagepoint': 166146,
#  'power': 116278,
#  'traders': 160951,
#  'our': 109807,
#  'hot': 67190,
#  'stocks': 141140,
#  'outlook': 110617,
#  'jcdacswlo': 78799,
#  'see why': 133516,
#  'why unitedrentals': 172812,
#  'unitedrentals uri': 164166,
#  'uri is': 165122,
#  'is trend': 76365,
#  'trend vantagepoint': 161523,
#  'vantagepoint power': 166149,
#  'power traders': 116366,
#  'traders are': 160952,
#  'are watching': 11108,
#  'watching in': 169093,
#  'in our': 70975,
#  'our hot': 109997,
#  'hot stocks': 67214,
#  'stocks outlook': 141172,
#  'outlook co': 110618,
#  'co jcdacswlo': 29656,
#  'see why unitedrentals': 133519,
#  'why unitedrentals uri': 172813,
#  'unitedrentals uri is': 164167,
#  'uri is trend': 165123,
#  'is trend vantagepoint': 76366,
#  'trend vantagepoint power': 161524,
#  'vantagepoint power traders': 166150,
#  'power traders are': 116367,
#  'traders are watching': 160953,
#  'are watching in': 11109,
#  'watching in our': 169094,
#  'in our hot': 70980,
#  'our hot stocks': 109998,
#  'hot stocks outlook': 67216,
#  'stocks outlook co': 141173,
#  'outlook co jcdacswlo': 110620,
#  'rt': 125699,
#  'modi_juma': 94798,
#  'before': 17041,
#  'you': 177603,
#  'cut': 36818,
#  'down': 42683,
#  'tree': 161465,
#  'think': 154009,
#  'about': 399,
#  'this': 154200,
#  'being': 17282,
#  'rainy': 120023,
#  'season': 133038,
#  'lets': 84953,
#  'take': 143809,
#  'own': 111004,
#  'initiatives': 73300,
#  'plant': 114573,
#  'trees': 161480,
#  'ho': 66491,
#  'rt modi_juma': 128468,
#  'modi_juma before': 94799,
#  'before you': 17140,
#  'you cut': 177842,
#  'cut down': 36821,
#  'down tree': 42914,
#  'tree think': 161478,
#  'think about': 154010,
#  'about this': 687,
#  'this being': 154243,
#  'being rainy': 17374,
#  'rainy season': 120024,
#  'season lets': 133068,
#  'lets take': 84966,
#  'take our': 143902,
#  'our own': 110091,
#  'own initiatives': 111061,
#  'initiatives to': 73303,
#  'to plant': 158312,
#  'plant trees': 114591,
#  'trees in': 161483,
#  'our ho': 109991,
#  'rt modi_juma before': 128469,
#  'modi_juma before you': 94800,
#  'before you cut': 17141,
#  'you cut down': 177843,
#  'cut down tree': 36823,
#  'down tree think': 42915,
#  'tree think about': 161479,
#  'think about this': 154014,
#  'about this being': 688,
#  'this being rainy': 154244,
#  'being rainy season': 17375,
#  'rainy season lets': 120025,
#  'season lets take': 133069,
#  'lets take our': 84967,
#  'take our own': 143903,
#  'our own initiatives': 110094,
#  'own initiatives to': 111062,
#  'initiatives to plant': 73304,
#  'to plant trees': 158313,
#  'plant trees in': 114592,
#  'trees in our': 161484,
#  'in our ho': 70979,
#  'ewtnews': 47929,
#  'fr': 54596,
#  'vincent': 167045,
#  'woo': 175173,
#  'brave': 20979,
#  'priest': 117352,
#  'diocese': 40611,
#  'hong': 66892,
#  'kong': 82474,
#  'joined': 79650,
#  'raymondarroyo': 120629,
#  'on': 106851,
#  'worldoverlive': 175722,
#  'last': 83287,
#  'night': 100809,
#  'discuss': 40890,
#  'com': 32275,
#  'rt ewtnews': 127074,
#  'ewtnews fr': 47930,
#  'fr vincent': 54599,
#  'vincent woo': 167046,
#  'woo brave': 175174,
#  'brave priest': 20987,
#  'priest of': 117353,
#  'of the': 105461,
#  'the diocese': 148229,
#  'diocese of': 40612,
#  'of hong': 104450,
#  'hong kong': 66893,
#  'kong joined': 82475,
#  'joined raymondarroyo': 79659,
#  'raymondarroyo on': 120630,
#  'on worldoverlive': 107943,
#  'worldoverlive last': 175723,
#  'last night': 83350,
#  'night to': 100850,
#  'to discuss': 157093,
#  'discuss com': 40895,
#  'rt ewtnews fr': 127075,
#  'ewtnews fr vincent': 47931,
#  'fr vincent woo': 54600,
#  'vincent woo brave': 167047,
#  'woo brave priest': 175175,
#  'brave priest of': 20988,
#  'priest of the': 117354,
#  'of the diocese': 105517,
#  'the diocese of': 148230,
#  'diocese of hong': 40613,
#  'of hong kong': 104451,
#  'hong kong joined': 66894,
#  'kong joined raymondarroyo': 82476,
#  'joined raymondarroyo on': 79660,
#  'raymondarroyo on worldoverlive': 120631,
#  'on worldoverlive last': 107944,
#  'worldoverlive last night': 175724,
#  'last night to': 83356,
#  'night to discuss': 100852,
#  'to discuss com': 157094,
#  'how': 67469,
#  'buy': 23079,
#  'marvin_inu': 90957,
#  'marvin': 90700,
#  'guide': 61254,
#  'binance': 18965,
#  'some': 138134,
#  'cryptocurrencies': 36345,
#  'harder': 62330,
#  'obtain': 103365,
#  'than': 145729,
#  'others': 109733,
#  'marvi': 90691,
#  'fjjpbooc': 51727,
#  'how to': 67724,
#  'to buy': 156728,
#  'buy marvin_inu': 23121,
#  'marvin_inu marvin': 90998,
#  'marvin guide': 90772,
#  'guide binance': 61255,
#  'binance some': 18974,
#  'some cryptocurrencies': 138155,
#  'cryptocurrencies are': 36348,
#  'are harder': 10646,
#  'harder to': 62337,
#  'to obtain': 158183,
#  'obtain than': 103370,
#  'than others': 145908,
#  'others marvi': 109748,
#  'marvi co': 90692,
#  'co fjjpbooc': 29160,
#  'how to buy': 67729,
#  'to buy marvin_inu': 156736,
#  'buy marvin_inu marvin': 23122,
#  'marvin_inu marvin guide': 91004,
#  'marvin guide binance': 90773,
#  'guide binance some': 61256,
#  'binance some cryptocurrencies': 18975,
#  'some cryptocurrencies are': 138156,
#  'cryptocurrencies are harder': 36349,
#  'are harder to': 10647,
#  'harder to obtain': 62340,
#  'to obtain than': 158186,
#  'obtain than others': 103371,
#  'than others marvi': 145910,
#  'others marvi co': 109749,
#  'marvi co fjjpbooc': 90693,
#  'wbzsausville': 169331,
#  'walkforvetsorg': 167927,
#  'john': 79408,
#  'ring': 124698,
#  'right': 124435,
#  'has': 62441,
#  'walked': 167914,
#  'nearly': 99055,
#  'miles': 93681,
#  'raise': 120026,
#  'awareness': 14031,
#  'veterans': 166729,
#  'suffering': 142502,
#  'invisible': 74434,
#  'rt wbzsausville': 130244,
#  'wbzsausville walkforvetsorg': 169374,
#  'walkforvetsorg john': 167928,
#  'john ring': 79423,
#  'ring right': 124699,
#  'right has': 124487,
#  'has walked': 62912,
#  'walked nearly': 167917,
#  'nearly miles': 99066,
#  'miles to': 93686,
#  'to raise': 158462,
#  'raise awareness': 120027,
#  'awareness of': 14038,
#  'of veterans': 105903,
#  'veterans suffering': 166730,
#  'suffering the': 142511,
#  'the invisible': 149284,
#  'rt wbzsausville walkforvetsorg': 130266,
#  'wbzsausville walkforvetsorg john': 169375,
#  'walkforvetsorg john ring': 167929,
#  'john ring right': 79424,
#  'ring right has': 124700,
#  'right has walked': 124488,
#  'has walked nearly': 62913,
#  'walked nearly miles': 167918,
#  'nearly miles to': 99067,
#  'miles to raise': 93688,
#  'to raise awareness': 158463,
#  'raise awareness of': 120028,
#  'awareness of veterans': 14039,
#  'of veterans suffering': 105904,
#  'veterans suffering the': 166731,
#  'suffering the invisible': 142512,
#  'rockyrick': 125204,
#  'sid_reddy': 135977,
#  'immivoice': 69474,
#  'your': 178685,
#  'selfish': 133773,
#  'interests': 73821,
#  'lt': 88195,
#  'literally': 86221,
#  'everyone': 47726,
#  'else': 45560,
#  'rockyrick sid_reddy': 125205,
#  'sid_reddy immivoice': 135978,
#  'immivoice your': 69475,
#  'your own': 179032,
#  'own selfish': 111104,
#  'selfish interests': 133774,
#  'interests lt': 73824,
#  'lt the': 88210,
#  'the good': 148861,
#  'good of': 59363,
#  'of literally': 104700,
#  'literally everyone': 86228,
#  'everyone else': 47731,
#  'rockyrick sid_reddy immivoice': 125206,
#  'sid_reddy immivoice your': 135979,
#  'immivoice your own': 69476,
#  'your own selfish': 179044,
#  'own selfish interests': 111105,
#  'selfish interests lt': 133775,
#  'interests lt the': 73825,
#  'lt the good': 88211,
#  'the good of': 148867,
#  'good of literally': 59364,
#  'of literally everyone': 104701,
#  'literally everyone else': 86229,
#  'realharveymark': 121348,
#  'interesting': 73752,
#  'perspective': 113613,
#  've': 166251,
#  'never': 99514,
#  'thought': 155220,
#  'it': 76801,
#  'way': 169183,
#  'when': 171549,
#  'hear': 64454,
#  'read': 120990,
#  'those': 155107,
#  'txqfue': 163030,
#  'realharveymark this': 121353,
#  'this is': 154521,
#  'is an': 74755,
#  'an interesting': 6259,
#  'interesting perspective': 73778,
#  'perspective and': 113614,
#  'and ve': 8586,
#  've never': 166327,
#  'never thought': 99612,
#  'thought of': 155236,
#  'of it': 104570,
#  'it this': 77729,
#  'this way': 154976,
#  'way when': 169271,
#  'when hear': 171606,
#  'hear and': 64461,
#  'and read': 8059,
#  'read those': 121046,
#  'those co': 155121,
#  'co txqfue': 31062,
#  'realharveymark this is': 121354,
#  'this is an': 154525,
#  'is an interesting': 74774,
#  'an interesting perspective': 6262,
#  'interesting perspective and': 73779,
#  'perspective and ve': 113615,
#  'and ve never': 8587,
#  've never thought': 166330,
#  'never thought of': 99614,
#  'thought of it': 155237,
#  'of it this': 104577,
#  'it this way': 77731,
#  'this way when': 154979,
#  'way when hear': 169272,
#  'when hear and': 171607,
#  'hear and read': 64462,
#  'and read those': 8060,
#  'read those co': 121047,
#  'those co txqfue': 155122,
#  'japan': 78649,
#  'continues': 34073,
#  'yield': 177482,
#  'curve': 36749,
#  'control': 34157,
#  'while': 172064,
#  'other': 109544,
#  'countries': 34884,
#  'just': 80208,
#  'beginning': 17173,
#  'rates': 120503,
#  'looks': 87450,
#  'like': 85566,
#  'currency': 36656,
#  'goujxdl': 59844,
#  'japan continues': 78656,
#  'continues yield': 34093,
#  'yield curve': 177487,
#  'curve control': 36752,
#  'control while': 34200,
#  'while other': 172119,
#  'other countries': 109569,
#  'countries are': 34890,
#  'are just': 10692,
#  'just beginning': 80250,
#  'beginning to': 17181,
#  'raise rates': 120037,
#  'rates looks': 120535,
#  'looks like': 87465,
#  'like currency': 85603,
#  'currency co': 36662,
#  'co goujxdl': 29313,
#  'japan continues yield': 78657,
#  'continues yield curve': 34094,
#  'yield curve control': 177488,
#  'curve control while': 36753,
#  'control while other': 34201,
#  'while other countries': 172121,
#  'other countries are': 109571,
#  'countries are just': 34891,
#  'are just beginning': 10695,
#  'just beginning to': 80251,
#  'beginning to raise': 17183,
#  'to raise rates': 158466,
#  'raise rates looks': 120039,
#  'rates looks like': 120536,
#  'looks like currency': 87466,
#  'like currency co': 85604,
#  'currency co goujxdl': 36663,
#  'prime': 117377,
#  'minister': 94074,
#  'announces': 9070,
#  'construction': 33865,
#  'modern': 94745,
#  'ayush': 14182,
#  'hospital': 67133,
#  'mauritius': 91676,
#  'pravindjugnauth': 116602,
#  'ayushhospital': 14189,
#  'zescpdrasb': 179657,
#  'prime minister': 117380,
#  'minister announces': 94077,
#  'announces construction': 9073,
#  'construction of': 33870,
#  'of modern': 104866,
#  'modern ayush': 94748,
#  'ayush hospital': 14187,
#  'hospital in': 67138,
#  'in mauritius': 70790,
#  'mauritius pravindjugnauth': 91684,
#  'pravindjugnauth ayushhospital': 116603,
#  'ayushhospital co': 14190,
#  'co zescpdrasb': 31760,
#  'prime minister announces': 117381,
#  'minister announces construction': 94078,
#  'announces construction of': 9074,
#  'construction of modern': 33871,
#  'of modern ayush': 104868,
#  'modern ayush hospital': 94749,
#  'ayush hospital in': 14188,
#  'hospital in mauritius': 67139,
#  'in mauritius pravindjugnauth': 70793,
#  'mauritius pravindjugnauth ayushhospital': 91685,
#  'pravindjugnauth ayushhospital co': 116604,
#  'ayushhospital co zescpdrasb': 14191,
#  'vijayjdarda': 166999,
#  'impossible': 69747,
#  'fully': 56113,
#  'give': 58124,
#  'back': 14336,
#  'mother': 96358,
#  'earth': 44145,
#  'which': 171943,
#  'gives': 58231,
#  'us': 165144,
#  'so': 137379,
#  'much': 96968,
#  'every': 47586,
#  'day': 37580,
#  'minute': 94232,
#  'second': 133115,
#  'we': 169408,
#  'rt vijayjdarda': 130173,
#  'vijayjdarda it': 167002,
#  'it is': 77266,
#  'is impossible': 75394,
#  'impossible to': 69754,
#  'to fully': 157415,
#  'fully give': 56116,
#  'give back': 58131,
#  'back to': 14415,
#  'to mother': 158101,
#  'mother earth': 96369,
#  'earth which': 44189,
#  'which gives': 171971,
#  'gives us': 58252,
#  'us so': 165349,
#  'so much': 137593,
#  'much every': 97016,
#  'every day': 47604,
#  'day every': 37648,
#  'every minute': 47639,
#  'minute every': 94239,
#  'every second': 47660,
#  'second but': 133118,
#  'but we': 23001,
#  'rt vijayjdarda it': 130174,
#  'vijayjdarda it is': 167003,
#  'it is impossible': 77286,
#  'is impossible to': 75395,
#  'impossible to fully': 69755,
#  'to fully give': 157416,
#  'fully give back': 56117,
#  'give back to': 58132,
#  'back to mother': 14423,
#  'to mother earth': 158102,
#  'mother earth which': 96371,
#  'earth which gives': 44190,
#  'which gives us': 171972,
#  'gives us so': 58254,
#  'us so much': 165350,
#  'so much every': 137599,
#  'much every day': 97017,
#  'every day every': 47605,
#  'day every minute': 37649,
#  'every minute every': 47640,
#  'minute every second': 94240,
#  'every second but': 47661,
#  'second but we': 133119,
#  'aylin': 14170,
#  'miltonkeynes': 93899,
#  'today': 159537,
#  'for': 52570,
#  'full': 56018,
#  'details': 39774,
#  'please': 114793,
#  'go': 58521,
#  'her': 64898,
#  'online': 108395,
#  'profile': 117898,
#  'fridayfeeling': 55011,
#  'whqfvlu': 172622,
#  'aylin is': 14171,
#  'is in': 75398,
#  'in miltonkeynes': 70820,
#  'miltonkeynes today': 93900,
#  'today for': 159609,
#  'for full': 53019,
#  'full details': 56034,
#  'details please': 39804,
#  'please go': 114822,
#  'go to': 58627,
#  'to her': 157628,
#  'her online': 64967,
#  'online profile': 108414,
#  'profile fridayfeeling': 117901,
#  'fridayfeeling co': 55012,
#  'co whqfvlu': 31383,
#  'aylin is in': 14172,
#  'is in miltonkeynes': 75411,
#  'in miltonkeynes today': 70821,
#  'miltonkeynes today for': 93901,
#  'today for full': 159611,
#  'for full details': 53020,
#  'full details please': 56035,
#  'details please go': 39805,
#  'please go to': 114823,
#  'go to her': 58629,
#  'to her online': 157630,
#  'her online profile': 64968,
#  'online profile fridayfeeling': 108416,
#  'profile fridayfeeling co': 117902,
#  'fridayfeeling co whqfvlu': 55028,
#  'petenajarian': 113640,
#  'mitchcer': 94519,
#  'old': 106631,
#  'fashioned': 49781,
#  'infused': 73248,
#  'with': 173851,
#  'cherry': 26976,
#  'smoke': 137283,
#  'well': 170603,
#  'done': 42418,
#  'burbon': 22364,
#  'possibilites': 115961,
#  'ckpzndbiyg': 27709,
#  'petenajarian mitchcer': 113645,
#  'mitchcer old': 94520,
#  'old fashioned': 106660,
#  'fashioned infused': 49782,
#  'infused with': 73249,
#  'with cherry': 173945,
#  'cherry smoke': 26977,
#  'smoke well': 137290,
#  'well done': 170647,
#  'done burbon': 42431,
#  'burbon possibilites': 22365,
#  'possibilites co': 115962,
#  'co ckpzndbiyg': 28774,
#  'petenajarian mitchcer old': 113646,
#  'mitchcer old fashioned': 94521,
#  'old fashioned infused': 106661,
#  'fashioned infused with': 49783,
#  'infused with cherry': 73250,
#  'with cherry smoke': 173946,
#  'cherry smoke well': 26978,
#  'smoke well done': 137291,
#  'well done burbon': 170651,
#  'done burbon possibilites': 42432,
#  'burbon possibilites co': 22366,
#  'possibilites co ckpzndbiyg': 115963,
#  'reccawoodruff': 121756,
#  'absolutely': 820,
#  'reccawoodruff absolutely': 121757,
#  'jawo': 78718,
#  'marvininu': 91074,
#  'can': 24137,
#  'help': 64742,
#  'dreams': 43205,
#  'come': 32312,
#  'true': 161917,
#  'now': 102431,
#  'bscgems': 21842,
#  'bscgemsalert': 21855,
#  'bnb': 19914,
#  'eth': 47012,
#  'rt jawo': 127711,
#  'jawo marvininu': 78733,
#  'marvininu can': 91103,
#  'can help': 24321,
#  'help your': 64820,
#  'your dreams': 178804,
#  'dreams come': 43208,
#  'come true': 32391,
#  'true buy': 161929,
#  'buy marvin': 23114,
#  'marvin now': 90873,
#  'now marvin_inu': 102651,
#  'marvin bscgems': 90725,
#  'bscgems bscgemsalert': 21843,
#  'bscgemsalert bnb': 21858,
#  'bnb eth': 19935,
#  'eth co': 47034,
#  'rt jawo marvininu': 127719,
#  'jawo marvininu can': 78734,
#  'marvininu can help': 91104,
#  'can help your': 24324,
#  'help your dreams': 64821,
#  'your dreams come': 178806,
#  'dreams come true': 43209,
#  'come true buy': 32393,
#  'true buy marvin': 161930,
#  'buy marvin now': 23118,
#  'marvin now marvin_inu': 90877,
#  'now marvin_inu marvin': 102653,
#  'marvin_inu marvin bscgems': 91002,
#  'marvin bscgems bscgemsalert': 90726,
#  'bscgems bscgemsalert bnb': 21844,
#  'bscgemsalert bnb eth': 21859,
#  'bnb eth co': 19939,
#  'kylegriffin': 82744,
#  'flag': 51745,
#  'washington': 168910,
#  'ap': 9680,
#  'capitol': 24861,
#  'order': 109299,
#  'evacuation': 47274,
#  'complex': 33137,
#  'citing': 27586,
#  'aircraft': 3205,
#  'that': 146142,
#  'poses': 115889,
#  'probable': 117603,
#  'thre': 155299,
#  'rt kylegriffin': 128050,
#  'kylegriffin flag': 82747,
#  'flag washington': 51774,
#  'washington ap': 168911,
#  'ap us': 9700,
#  'us capitol': 165190,
#  'capitol police': 24866,
#  'police order': 115348,
#  'order evacuation': 109308,
#  'evacuation of': 47275,
#  'of capitol': 103811,
#  'capitol complex': 24864,
#  'complex citing': 33138,
#  'citing aircraft': 27587,
#  'aircraft that': 3208,
#  'that poses': 146731,
#  'poses probable': 115890,
#  'probable thre': 117604,
#  'rt kylegriffin flag': 128052,
#  'kylegriffin flag washington': 82748,
#  'flag washington ap': 51775,
#  'washington ap us': 168912,
#  'ap us capitol': 9701,
#  'us capitol police': 165191,
#  'capitol police order': 24867,
#  'police order evacuation': 115349,
#  'order evacuation of': 109309,
#  'evacuation of capitol': 47276,
#  'of capitol complex': 103812,
#  'capitol complex citing': 24865,
#  'complex citing aircraft': 33139,
#  'citing aircraft that': 27588,
#  'aircraft that poses': 3209,
#  'that poses probable': 146732,
#  'poses probable thre': 115891,
#  'drshamamohd': 43471,
#  'if': 68713,
#  'pm': 114989,
#  'modi': 94775,
#  'not': 101666,
#  'afraid': 2184,
#  'audit': 13589,
#  'doesn': 41834,
#  'agree': 2866,
#  'sc': 132490,
#  'monitored': 95147,
#  'probe': 117627,
#  'into': 73958,
#  'rafalescam': 119911,
#  'especially': 46831,
#  'light': 85512,
#  'rt drshamamohd': 126877,
#  'drshamamohd if': 43474,
#  'if pm': 68848,
#  'pm modi': 115044,
#  'modi is': 94784,
#  'is not': 75706,
#  'not afraid': 101677,
#  'afraid of': 2187,
#  'of an': 103606,
#  'an audit': 6068,
#  'audit why': 13596,
#  'why doesn': 172682,
#  'doesn he': 41868,
#  'he agree': 63975,
#  'agree to': 2898,
#  'to sc': 158686,
#  'sc monitored': 132495,
#  'monitored probe': 95148,
#  'probe into': 117630,
#  'into rafalescam': 74065,
#  'rafalescam especially': 119912,
#  'especially in': 46837,
#  'in light': 70701,
#  'rt drshamamohd if': 126879,
#  'drshamamohd if pm': 43475,
#  'if pm modi': 68849,
#  'pm modi is': 115045,
#  'modi is not': 94785,
#  'is not afraid': 75707,
#  'not afraid of': 101678,
#  'afraid of an': 2188,
#  'of an audit': 103609,
#  'an audit why': 6069,
#  'audit why doesn': 13597,
#  'why doesn he': 172683,
#  'doesn he agree': 41869,
#  'he agree to': 63976,
#  'agree to sc': 2899,
#  'to sc monitored': 158687,
#  'sc monitored probe': 132496,
#  'monitored probe into': 95149,
#  'probe into rafalescam': 117631,
#  'into rafalescam especially': 74066,
#  'rafalescam especially in': 119913,
#  'especially in light': 46838,
#  'libsoftiktok': 85284,
#  'example': 48014,
#  'educator': 44871,
#  'who': 172244,
#  'lost': 87660,
#  'their': 152337,
#  'job': 79266,
#  'after': 2283,
#  'posted': 116045,
#  'video': 166887,
#  'professor': 117888,
#  'wants': 168198,
#  'destigmatiz': 39682,
#  'rt libsoftiktok': 128121,
#  'libsoftiktok this': 85287,
#  'an example': 6146,
#  'example of': 48019,
#  'an educator': 6104,
#  'educator who': 44872,
#  'who lost': 172421,
#  'lost their': 87698,
#  'their job': 152460,
#  'job after': 79269,
#  ...}

# %%
df = pd.DataFrame(trigram_vectorizer.vocabulary_.items(),columns=['Vocabulary','Frequency'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180016 entries, 0 to 180015
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Vocabulary  180016 non-null  object
#  1   Frequency   180016 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.7+ MB

# %%
df = df.sort_values(by='Frequency',ascending=False)

# %%
df.head(20)
# Out:
#                         Vocabulary  Frequency
# 15884              𝙈𝙆𝙎𝙩𝙖𝙡𝙞𝙣𝟺𝗣𝗠𝟸𝟶𝟸𝟺     180015
# 96801            𝘄𝗼𝗿𝗹𝗱 𝗵𝗮𝘀 𝗰𝗵𝗮𝗻𝗴𝗲𝗱     180014
# 96779                    𝘄𝗼𝗿𝗹𝗱 𝗵𝗮𝘀     180013
# 96758                        𝘄𝗼𝗿𝗹𝗱     180012
# 96799              𝘄𝗵𝗶𝗰𝗵 𝘁𝗵𝗲 𝘄𝗼𝗿𝗹𝗱     180011
# 96777                    𝘄𝗵𝗶𝗰𝗵 𝘁𝗵𝗲     180010
# 96756                        𝘄𝗵𝗶𝗰𝗵     180009
# 96797                𝘄𝗮𝘆𝘀 𝗶𝗻 𝘄𝗵𝗶𝗰𝗵     180008
# 96775                      𝘄𝗮𝘆𝘀 𝗶𝗻     180007
# 96754                         𝘄𝗮𝘆𝘀     180006
# 96800                𝘁𝗵𝗲 𝘄𝗼𝗿𝗹𝗱 𝗵𝗮𝘀     180005
# 96778                    𝘁𝗵𝗲 𝘄𝗼𝗿𝗹𝗱     180004
# 96757                          𝘁𝗵𝗲     180003
# 110235  𝗿𝗲𝗮𝗱𝘆 mm_footballclub mufc     180002
# 110227       𝗿𝗲𝗮𝗱𝘆 mm_footballclub     180001
# 110220                       𝗿𝗲𝗮𝗱𝘆     180000
# 96798                 𝗶𝗻 𝘄𝗵𝗶𝗰𝗵 𝘁𝗵𝗲     179999
# 96776                     𝗶𝗻 𝘄𝗵𝗶𝗰𝗵     179998
# 96755                           𝗶𝗻     179997
# 96780                  𝗵𝗮𝘀 𝗰𝗵𝗮𝗻𝗴𝗲𝗱     179996

# %%
df.tail(20)
# Out:
#                                            Vocabulary  Frequency
# 142157                       _borutoking alex_dreyfus         19
# 47155                                     _borutoking         18
# 130961                              _are_ possible if         17
# 130948                                 _are_ possible         16
# 130938                                          _are_         15
# 42642                      _anti_hypocrite jrntr fans         14
# 42624                           _anti_hypocrite jrntr         13
# 42613                                 _anti_hypocrite         12
# 68399                          _africanunion don miss         11
# 68392                               _africanunion don         10
# 68388                                   _africanunion          9
# 99034   __h__e__a__c__ robertbradleyj tpostmillennial          8
# 99028                   __h__e__a__c__ robertbradleyj          7
# 99025                                  __h__e__a__c__          6
# 54449                          __anncheese night gain          5
# 54441                               __anncheese night          4
# 54438                                     __anncheese          3
# 95226                         ____sj follow aitcrupak          2
# 95225                                   ____sj follow          1
# 95224                                          ____sj          0

# %%
X_train_trigram = trigram_vectorizer.transform(X_train.values)

# %% [markdown]
# Trigram Tf-Idf

# %%
trigram_tf_idf_transformer = TfidfTransformer()
trigram_tf_idf_transformer.fit(X_train_trigram)
X_train_trigram_tf_idf = trigram_tf_idf_transformer.transform(X_train_trigram)

# %% [markdown]
# SGD Classifier

# %%
def train_and_show_scores(X: csr_matrix, y: np.array, title: str) -> None:
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, test_size=0.75, stratify=y
    )

    clf = SGDClassifier()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    valid_score = clf.score(X_valid, y_valid)
    print(f'{title}\nTrain score: {round(train_score, 2)} ; Validation score: {round(valid_score, 2)}\n')

# %%
train_and_show_scores(X_train_trigram, y_train.values, 'Trigram Counts')
train_and_show_scores(X_train_trigram_tf_idf, y_train.values, 'Trigram Tf-Idf')
# Out:
# Trigram Counts
# Train score: 1.0 ; Validation score: 0.76
#
# Trigram Tf-Idf
# Train score: 1.0 ; Validation score: 0.73

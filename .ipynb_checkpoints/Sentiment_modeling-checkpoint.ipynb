# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

import numpy as np # linear algebra
from scipy.stats import uniform
from scipy.sparse import csr_matrix

# %matplotlib inline

# %%
# Import the data
tweet_df = pd.read_csv("clean_preprocessed.csv")
tweet_df.columns
tweet_df = tweet_df.rename(columns={'preproc_text':'clean_text'})
cleanTweet = tweet_df.copy()[["clean_text","polarity"]]

# %%
# Define the sentiment carrying in the text
def text_category(tweet_polarity):
    '''A function to return the sentiment carried by a tweet text'''
    if tweet_polarity>0:
        return "positive"
    elif tweet_polarity<0:
        return "negative"
    else:
        return "neutral"

# %%
cleanTweet["score"] = cleanTweet["polarity"].apply(text_category)
score_sent = cleanTweet["score"].value_counts()
score_sent
# Out:
# neutral     6932
# positive    5722
# negative    2428
# Name: score, dtype: int64

# %%
plt.bar(score_sent.index,score_sent.values)
plt.show()

# %%
fig,ax = plt.subplots(1,2)
ax[0].bar(score_sent.index,score_sent.values)
ax[1].pie(score_sent,labels=['neutral','positive','negative'])
plt.show()

# %%
# Extract the positive and negative
cleanTweet = cleanTweet[cleanTweet["score"]!="neutral"]
cleanTweet["score"].value_counts()
# Out:
# positive    5722
# negative    2428
# Name: score, dtype: int64

# %%
# Re-index the frame
cleanTweet = cleanTweet.reset_index(drop=True)
cleanTweet
# Out:
#                                              clean_text  polarity     score
# 0     rt @northstarcharts: the -year yield is tellin...  0.160000  positive
# 1     rt @michaelaarouet: german y mortgage rate wen...  0.150000  positive
# 2     rt @biancoresearch: rates rise until something... -0.400000  negative
# 3     rt @lanceroberts: buying opportunities like th... -0.100000  negative
# 4     rt @macroalf: welcome to september .\n\nbond m...  0.400000  positive
# ...                                                 ...       ...       ...
# 8145  rt @ferozkhaninc: in #telangana rapes, murders...  0.095455  positive
# 8146  rt @ozamizcps: pssg gedson castañeros, mobile ...  0.100000  positive
# 8147  rt @salt_project_os: free yourself from writin...  0.400000  positive
# 8148  rt @pbhushan: thank you @bajpayeemanoj for thi...  0.850000  positive
# 8149  rt @tejjinc: . peace yatra by late sunil dutt ... -0.300000  negative
#
# [8150 rows x 3 columns]

# %%
# Create a function to encode the sentiment
def encode_sentiment(sentiment):
    '''Encode the sentiment. 1 if positive, 0 otherwise'''
    if sentiment=="positive":
        return 1
    else: return 0

# %%
cleanTweet['scoremap'] = cleanTweet['score'].apply(encode_sentiment)
cleanTweet['scoremap'].describe()
# Out:
# count    8150.000000
# mean        0.702086
# std         0.457370
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: scoremap, dtype: float64

# %%
# Create features and target variable
(X,y) = (cleanTweet['clean_text'],cleanTweet['scoremap'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
# Create the trigram vectorize
trigram_vectorizer = CountVectorizer(ngram_range=(3, 3))
trigram_vectorizer.fit(X_train.values)
# Out:
# CountVectorizer(ngram_range=(3, 3))

# %%
trigram_vectorizer.vocabulary_
# Out:
# {'we must stop': 82328,
#  'must stop this': 45732,
#  'stop this filthy': 66948,
#  'this filthy killing': 74300,
#  'filthy killing in': 22708,
#  'killing in ukraine': 38413,
#  'systemsninja she looks': 68013,
#  'she looks gorgeous': 64022,
#  'rt pulte lupus': 61259,
#  'pulte lupus is': 56297,
#  'lupus is terrible': 41450,
#  'is terrible disease': 35665,
#  'terrible disease sent': 68784,
#  'disease sent you': 18127,
#  'sent you so': 63643,
#  'you so you': 86988,
#  'so you can': 65318,
#  'you can get': 86542,
#  'can get your': 12048,
#  'get your medicine': 26153,
#  'the only limit': 71828,
#  'only limit to': 51521,
#  'limit to your': 40300,
#  'to your prosperity': 77509,
#  'your prosperity is': 87389,
#  'prosperity is the': 56084,
#  'is the lack': 35727,
#  'the lack of': 71247,
#  'lack of belief': 38828,
#  'of belief in': 48649,
#  'belief in your': 8833,
#  'in your own': 33397,
#  'your own vision': 87369,
#  'own vision and': 52829,
#  'vision and ability': 80994,
#  'and ability lineappofficial': 3095,
#  'ability lineappofficial co': 124,
#  'lineappofficial co zjjtqqhx': 40343,
#  'moody decline in': 44632,
#  'decline in bad': 17082,
#  'in bad loans': 32208,
#  'bad loans to': 7432,
#  'loans to improve': 40731,
#  'to improve banks': 76309,
#  'improve banks profitability': 32109,
#  'banks profitability profit': 7629,
#  'profitability profit moodys': 55912,
#  'profit moodys co': 55905,
#  'moodys co vwjrtapoh': 44634,
#  'oh well cuppa': 50306,
#  'well cuppa and': 82791,
#  'cuppa and twitter': 16262,
#  'and twitter cheer': 4338,
#  'twitter cheer up': 79008,
#  'cheer up over': 13197,
#  'up over let': 79883,
#  'over let start': 52666,
#  'let start the': 39798,
#  'start the working': 66417,
#  'the working day': 72950,
#  'working day be': 85485,
#  'day be safe': 16662,
#  'be safe and': 8156,
#  'safe and just': 62426,
#  'and just smile': 3739,
#  'just smile all': 37857,
#  'rt smutoro guess': 61570,
#  'smutoro guess what': 65080,
#  'guess what kind': 27844,
#  'what kind of': 83119,
#  'kind of conversation': 38428,
#  'of conversation went': 48785,
#  'conversation went on': 15254,
#  'went on here': 82858,
#  'on here between': 50720,
#  'here between president': 29863,
#  'between president kenyatta': 9227,
#  'president kenyatta and': 55451,
#  'kenyatta and iron': 38215,
#  'and iron lady': 3688,
#  'iron lady of': 34702,
#  'lady of kirinyaga': 38847,
#  'of kirinyaga martha': 49172,
#  'kirinyaga martha karua': 38500,
#  'martha karua in': 42498,
#  'karua in vernacula': 38014,
#  'vintage european train': 80937,
#  'european train available': 21020,
#  'train available on': 78293,
#  'available on over': 7106,
#  'on over redbubble': 50873,
#  'over redbubble products': 52695,
#  'redbubble products stickers': 57684,
#  'products stickers tshirts': 55873,
#  'stickers tshirts mugs': 66736,
#  'tshirts mugs masks': 78822,
#  'mugs masks magnets': 45555,
#  'masks magnets co': 42868,
#  'magnets co dialbeoer': 41594,
#  'it has been': 36297,
#  'has been nice': 28483,
#  'been nice week': 8542,
#  'nice week looking': 47232,
#  'week looking forward': 82621,
#  'looking forward to': 41035,
#  'forward to the': 24589,
#  'to the weekend': 77297,
#  'the weekend so': 72901,
#  'weekend so bbq': 82672,
#  'so bbq time': 65114,
#  'bbq time meat': 7822,
#  'time meat from': 75093,
#  'meat from morleybutchers': 43363,
#  'from morleybutchers fish': 25101,
#  'morleybutchers fish from': 44956,
#  'fish from co': 23046,
#  'from co bjsydlsnl': 24991,
#  'the thescapas executive': 72613,
#  'thescapas executive judge': 73589,
#  'executive judge detlef': 21472,
#  'judge detlef schultz': 37613,
#  'detlef schultz is': 17667,
#  'schultz is the': 63069,
#  'is the co': 35696,
#  'the co founder': 70253,
#  'co founder vision': 13967,
#  'founder vision amp': 24642,
#  'vision amp customers': 80993,
#  'amp customers at': 2570,
#  'customers at akirolabs': 16327,
#  'at akirolabs learn': 6503,
#  'akirolabs learn more': 1589,
#  'learn more abo': 39462,
#  'more abo co': 44655,
#  'abo co yrdsauzpn': 160,
#  'indorama bn acquisition': 33804,
#  'bn acquisition of': 9943,
#  'acquisition of oxiteno': 584,
#  'of oxiteno provides': 49424,
#  'oxiteno provides it': 52860,
#  'provides it with': 56189,
#  'it with another': 36761,
#  'with another link': 84615,
#  'another link in': 4671,
#  'link in the': 40363,
#  'in the production': 33185,
#  'the production chain': 72070,
#  'production chain it': 55858,
#  'chain it has': 12880,
#  'it has spent': 36305,
#  'has spent the': 28692,
#  'spent the pas': 66027,
#  'the pas co': 71910,
#  'pas co awnltdwop': 53247,
#  'rt keepitkiss former': 60615,
#  'keepitkiss former rd': 38143,
#  'former rd president': 24546,
#  'rd president of': 57018,
#  'president of kenya': 55457,
#  'of kenya emilio': 49166,
#  'kenya emilio mwai': 38197,
#  'emilio mwai kibaki': 20349,
#  'mwai kibaki has': 45763,
#  'kibaki has passed': 38319,
#  'has passed on': 28655,
#  'passed on true': 53268,
#  'on true leader': 51143,
#  'true leader quintessential': 78652,
#  'leader quintessential statemanship': 39381,
#  'quintessential statemanship game': 56605,
#  'statemanship game change': 66531,
#  'exclusive employers are': 21456,
#  'employers are facing': 20404,
#  'are facing mental': 5340,
#  'facing mental health': 21784,
#  'mental health timebomb': 43611,
#  'health timebomb read': 29553,
#  'timebomb read more': 75182,
#  'read more on': 57167,
#  'more on rewardstrategy': 44821,
#  'on rewardstrategy co': 50913,
#  'rewardstrategy co rdiibddt': 58568,
#  'co rdiibddt co': 14113,
#  'rdiibddt co vxnftifns': 57027,
#  'don know why': 18754,
#  'know why the': 38666,
#  'why the hell': 84006,
#  'the hell traffic': 71021,
#  'hell traffic is': 29686,
#  'traffic is so': 78277,
#  'is so brutal': 35596,
#  'so brutal but': 65121,
#  'brutal but anyone': 10752,
#  'but anyone who': 11118,
#  'anyone who moved': 4880,
#  'who moved to': 83798,
#  'moved to ct': 45243,
#  'to ct during': 75820,
#  'ct during covid': 16208,
#  'during covid needs': 19495,
#  'covid needs to': 15718,
#  'needs to freaking': 46543,
#  'to freaking leave': 76080,
#  'fantstic day as': 22084,
#  'day as the': 16660,
#  'as the speaker': 6238,
#  'the speaker at': 72443,
#  'speaker at the': 65878,
#  'at the tech': 6814,
#  'the tech live': 72579,
#  'tech live stage': 68555,
#  'live stage today': 40555,
#  'stage today spoke': 66320,
#  'today spoke about': 77644,
#  'spoke about innovation': 66068,
#  'about innovation and': 226,
#  'innovation and the': 34114,
#  'and the how': 4230,
#  'the how the': 71085,
#  'how the original': 31189,
#  'the original desig': 71853,
#  'original desig co': 51952,
#  'desig co szrcbhybw': 17562,
#  'with flexsalary keep': 84716,
#  'flexsalary keep high': 23170,
#  'keep high interest': 38090,
#  'high interest huge': 30092,
#  'interest huge paperwork': 34267,
#  'huge paperwork fixed': 31303,
#  'paperwork fixed emis': 53057,
#  'fixed emis at': 23093,
#  'emis at bay': 20353,
#  'at bay install': 6527,
#  'bay install the': 7787,
#  'install the app': 34188,
#  'the app now': 69873,
#  'app now co': 4970,
#  'now co tlwukdppeb': 48135,
#  'rt jawo are': 60473,
#  'jawo are you': 37111,
#  'are you looking': 5733,
#  'you looking for': 86814,
#  'looking for the': 41033,
#  'for the right': 24217,
#  'the right investment': 72228,
#  'right investment marvininu': 58774,
#  'investment marvininu is': 34577,
#  'marvininu is the': 42770,
#  'is the investment': 35724,
#  'the investment you': 71173,
#  'investment you can': 34583,
#  'you can put': 86558,
#  'can put your': 12123,
#  'put your money': 56422,
#  'your money in': 87333,
#  'money in and': 44495,
#  'in and get': 32174,
#  'and get good': 3511,
#  'get good profit': 26042,
#  'good profit in': 26990,
#  'profit in re': 55900,
#  'amandamilling you re': 2310,
#  'you re so': 86930,
#  're so deep': 57111,
#  'so deep in': 65136,
#  'deep in the': 17117,
#  'in the lie': 33137,
#  'the lie you': 71354,
#  'lie you can': 39982,
#  'you can see': 86563,
#  'can see how': 12137,
#  'see how much': 63343,
#  'how much it': 31155,
#  'much it smells': 45479,
#  'it smells of': 36613,
#  'smells of bullshit': 65049,
#  'rt mattrockman s_mikhailovich': 60850,
#  'mattrockman s_mikhailovich what': 42971,
#  's_mikhailovich what goes': 62349,
#  'what goes up': 83076,
#  'goes up goes': 26620,
#  'up goes up': 79838,
#  'goes up and': 26619,
#  'up and up': 79795,
#  'and up and': 4356,
#  'and up until': 4357,
#  'up until it': 79948,
#  'until it goes': 79742,
#  'it goes down': 36274,
#  'goes down very': 26611,
#  'down very few': 19135,
#  'very few remember': 80695,
#  'few remember the': 22569,
#  'remember the last': 57971,
#  'the last part': 71275,
#  'rt wannabecoffee world': 61950,
#  'wannabecoffee world with': 81351,
#  'world with free': 85596,
#  'with free green': 84722,
#  'free green energy': 24719,
#  'green energy accessible': 27588,
#  'energy accessible to': 20514,
#  'accessible to everyone': 488,
#  'to everyone is': 75998,
#  'everyone is peaceful': 21266,
#  'is peaceful world': 35472,
#  'peaceful world greenenergy': 53548,
#  'world greenenergy co': 85557,
#  'greenenergy co hfqxpoggyb': 27625,
#  'rt millionairebiz see': 60900,
#  'millionairebiz see advice': 43989,
#  'see advice on': 63319,
#  'advice on here': 928,
#  'on here about': 50719,
#  'here about journaling': 29848,
#  'about journaling your': 237,
#  'journaling your trades': 37547,
#  'your trades well': 87440,
#  'trades well what': 78231,
#  'well what you': 82834,
#  'what you should': 83232,
#  'you should be': 86978,
#  'should be doing': 64284,
#  'be doing is': 7940,
#  'doing is selling': 18622,
#  'is selling your': 35569,
#  'selling your fucking': 63567,
#  'your fucking position': 87271,
#  'fucking position and': 25304,
#  'happy worldamateurradioday amateurradio': 28313,
#  'worldamateurradioday amateurradio hamradio': 85600,
#  'amateurradio hamradio co': 2313,
#  'hamradio co miflvxnnj': 28112,
#  'richard_norfolk he should': 58693,
#  'he should go': 29422,
#  'should go down': 64311,
#  'go down for': 26485,
#  'down for brexit': 19043,
#  'for brexit partygate': 23571,
#  'brexit partygate and': 10537,
#  'partygate and will': 53240,
#  'and will do': 4434,
#  'will do serious': 84208,
#  'do serious as': 18400,
#  'serious as it': 63681,
#  'as it was': 6103,
#  'it was the': 36728,
#  'was the wrong': 81798,
#  'the wrong thing': 73007,
#  'wrong thing months': 85899,
#  'thing months in': 73996,
#  'months in co': 44612,
#  'in co sdfpdwdot': 32327,
#  'rt biancoresearch remember': 59635,
#  'biancoresearch remember the': 9280,
#  'remember the fed': 57969,
#  'the fed wants': 70721,
#  'fed wants reverse': 22403,
#  'wants reverse wealth': 81446,
#  'reverse wealth effect': 58520,
#  'wealth effect dudley': 82506,
#  'effect dudley below': 20044,
#  'dudley below to': 19421,
#  'below to get': 8895,
#  'to get rich': 76118,
#  'get rich people': 26107,
#  'rich people defined': 58677,
#  'people defined as': 53675,
#  'defined as stock': 17180,
#  'as stock owners': 6209,
#  'stock owners to': 66858,
#  'owners to stop': 52853,
#  'to stop sp': 77083,
#  'unpopular opinion the': 79707,
#  'opinion the dc': 51670,
#  'the dc direct': 70449,
#  'dc direct to': 16855,
#  'direct to consumer': 18006,
#  'to consumer model': 75786,
#  'consumer model of': 15102,
#  'model of business': 44353,
#  'of business will': 48688,
#  'business will fail': 11073,
#  'will fail the': 84220,
#  'fail the middlemen': 21829,
#  'the middlemen distributors': 71532,
#  'middlemen distributors can': 43810,
#  'distributors can never': 18235,
#  'can never be': 12096,
#  'never be replaced': 46645,
#  'purvabhatia ah wish': 56365,
#  'ah wish it': 1402,
#  'wish it was': 84548,
#  'it was that': 36727,
#  'was that good': 81779,
#  'that good all': 69360,
#  'good all the': 26855,
#  'all the time': 1888,
#  'the time but': 72625,
#  'time but at': 75035,
#  'but at times': 11129,
#  'at times it': 6848,
#  'times it easy': 75206,
#  'it easy like': 36231,
#  'easy like this': 19813,
#  'like this one': 40235,
#  'this one pr': 74524,
#  'one pr folks': 51383,
#  'pr folks try': 55267,
#  'folks try so': 23328,
#  'try so hard': 78780,
#  'so hard to': 65185,
#  'hard to do': 28354,
#  'to do it': 75907,
#  'angel is in': 4514,
#  'is in miltonkeynes': 35167,
#  'in miltonkeynes tomorrow': 32741,
#  'miltonkeynes tomorrow for': 44016,
#  'tomorrow for full': 77786,
#  'for full details': 23726,
#  'full details please': 25400,
#  'details please go': 17656,
#  'please go to': 54514,
#  'go to her': 26534,
#  'to her online': 76264,
#  'her online profile': 29824,
#  'online profile fridayfeeling': 51461,
#  'profile fridayfeeling co': 55893,
#  'fridayfeeling co mecpqism': 24870,
#  'rt convertbond know': 59814,
#  'convertbond know that': 15265,
#  'know that families': 38618,
#  'that families are': 69336,
#  'families are still': 21965,
#  'are still struggling': 5609,
#  'still struggling with': 66811,
#  'struggling with higher': 67227,
#  'with higher prices': 84757,
#  'higher prices grew': 30173,
#  'prices grew up': 55610,
#  'grew up in': 27658,
#  'up in family': 79848,
#  'in family where': 32430,
#  'family where if': 22017,
#  'where if the': 83433,
#  'if the price': 31707,
#  'the price of': 72051,
#  'price of gas': 55553,
#  'of gas went': 48976,
#  'gas went up': 25767,
#  'went up we': 82867,
#  'rt neocapricoin cryptojack': 61023,
#  'neocapricoin cryptojack wow': 46589,
#  'cryptojack wow cheemsinu': 16170,
#  'wow cheemsinu ath': 85830,
#  'cheemsinu ath incoming': 13190,
#  'ath incoming cinu': 6880,
#  'incoming cinu till': 33484,
#  'cinu till die': 13484,
#  'till die cheems': 75007,
#  'die cheems cheemsinu': 17879,
#  'cheems cheemsinu bsc': 13186,
#  'cheemsinu bsc memetech': 13191,
#  'bsc memetech cronos': 10777,
#  'memetech cronos cheemsinuarmy': 43570,
#  'we hope this': 82282,
#  'hope this new': 30808,
#  'this new financial': 74500,
#  'new financial year': 46782,
#  'financial year brings': 22773,
#  'year brings wealth': 86062,
#  'brings wealth success': 10648,
#  'wealth success and': 82511,
#  'success and good': 67366,
#  'and good health': 3533,
#  'good health with': 26920,
#  'health with it': 29555,
#  'with it happy': 84787,
#  'it happy financial': 36294,
#  'happy financial year': 28266,
#  'financial year co': 22774,
#  'year co txldwflwlp': 86071,
#  'darlene is an': 16555,
#  'is an amazing': 34762,
#  'an amazing part': 2858,
#  'amazing part of': 2336,
#  'part of our': 53134,
#  'of our saratoga': 49414,
#  'our saratoga county': 52305,
#  'saratoga county community': 62715,
#  'county community an': 15600,
#  'community an activist': 14646,
#  'an activist for': 2837,
#  'activist for safer': 676,
#  'for safer streets': 24047,
#  'safer streets for': 62450,
#  'streets for everyone': 67117,
#  'for everyone and': 23692,
#  'everyone and public': 21254,
#  'and public co': 4027,
#  'public co rbclgpg': 56242,
#  'rt littlegee_x happy': 60742,
#  'littlegee_x happy easter': 40495,
#  'happy easter co': 28259,
#  'easter co xhrmqqef': 19780,
#  'this is the': 74417,
#  'is the level': 35734,
#  'the level of': 71350,
#  'level of intimidation': 39858,
#  'of intimidation from': 49119,
#  'intimidation from military': 34383,
#  'from military and': 25097,
#  'military and police': 43912,
#  'and police that': 4002,
#  'police that tamils': 54766,
#  'that tamils face': 69608,
#  'tamils face video': 68302,
#  'face video was': 21755,
#  'video was taken': 80883,
#  'was taken one': 81773,
#  'taken one year': 68159,
#  'one year ago': 51424,
#  'year ago in': 86040,
#  'ago in the': 1335,
#  'in the no': 33166,
#  'the no co': 71775,
#  'no co rlgveeamkb': 47381,
#  'rt theblaze florida': 61734,
#  'theblaze florida sheriff': 73073,
#  'florida sheriff says': 23236,
#  'sheriff says homeowners': 64080,
#  'says homeowners are': 62936,
#  'homeowners are more': 30720,
#  'are more than': 5460,
#  'more than welcome': 44905,
#  'than welcome to': 69094,
#  'welcome to shoot': 82751,
#  'to shoot at': 77008,
#  'shoot at crooks': 64172,
#  'at crooks who': 6559,
#  'crooks who break': 16013,
#  'who break into': 83708,
#  'break into their': 10445,
#  'into their homes': 34462,
#  'their homes we': 73169,
#  'homes we prefer': 30733,
#  'we prefer that': 82355,
#  'prefer that you': 55350,
#  'that you do': 69776,
#  'rt jabaribrisport for': 60433,
#  'jabaribrisport for those': 36959,
#  'for those not': 24280,
#  'those not following': 74752,
#  'not following the': 47756,
#  'following the ny': 23372,
#  'the ny state': 71791,
#  'ny state budget': 48401,
#  'state budget is': 66480,
#  'budget is late': 10868,
#  'is late because': 35242,
#  'late because at': 39129,
#  'because at the': 8324,
#  'at the th': 6815,
#  'the th hour': 72595,
#  'th hour of': 68923,
#  'hour of negotiations': 30934,
#  'of negotiations govkathyhochul': 49349,
#  'negotiations govkathyhochul decided': 46563,
#  'benvolin dropping salaries': 8961,
#  'dropping salaries to': 19369,
#  'salaries to weather': 62562,
#  'to weather the': 77437,
#  'weather the storm': 82555,
#  'the storm for': 72503,
#  'storm for few': 66996,
#  'for few years': 23707,
#  'few years no': 22591,
#  'years no point': 86204,
#  'no point spending': 47490,
#  'point spending money': 54709,
#  'spending money at': 66005,
#  'money at this': 44474,
#  'at this point': 6843,
#  'this point maybe': 74542,
#  'point maybe they': 54699,
#  'maybe they co': 43081,
#  'they co jfpqawn': 73751,
#  'greenpeaceusa ewg you': 27636,
#  'ewg you re': 21340,
#  'you re not': 86918,
#  're not environmentalists': 57083,
#  'not environmentalists you': 47733,
#  'environmentalists you re': 20722,
#  'you re idiots': 86912,
#  're idiots bitcoin': 57070,
#  'idiots bitcoin will': 31581,
#  'bitcoin will fix': 9663,
#  'will fix the': 84223,
#  'fix the world': 23088,
#  'rt berniespofforth ireland': 59625,
#  'berniespofforth ireland justice': 8976,
#  'ireland justice minister': 34683,
#  'justice minister the': 37911,
#  'minister the state': 44105,
#  'the state now': 72489,
#  'state now has': 66506,
#  'now has unlimited': 48163,
#  'has unlimited authority': 28723,
#  'unlimited authority over': 79693,
#  'authority over citizens': 7064,
#  'over citizens amp': 52635,
#  'citizens amp their': 13513,
#  'amp their free': 2778,
#  'their free will': 73158,
#  'free will the': 24762,
#  'will the government': 84394,
#  'the government wil': 70925,
#  'charlie living_woman _idontcomply_': 13071,
#  'living_woman _idontcomply_ look': 40624,
#  '_idontcomply_ look at': 21,
#  'look at it': 40973,
#  'at it now': 6603,
#  'it now this': 36498,
#  'now this really': 48272,
#  'this really isn': 74557,
#  'really isn right': 57429,
#  'isn right co': 36002,
#  'right co rcvasrsgxj': 58757,
#  'rt gain_mutualls am': 60177,
#  'gain_mutualls am following': 25619,
#  'am following all': 2262,
#  'following all who': 23366,
#  'all who retweets': 1920,
#  'who retweets this': 83816,
#  'retweets this and': 58479,
#  'this and follows': 74192,
#  'and follows me': 3467,
#  'follows me quickly': 23379,
#  'netflix has warned': 46607,
#  'has warned of': 28728,
#  'warned of global': 81514,
#  'of global crackdown': 48988,
#  'global crackdown on': 26415,
#  'crackdown on account': 15809,
#  'on account sharing': 50495,
#  'account sharing it': 520,
#  'sharing it is': 63935,
#  'it is estimated': 36356,
#  'is estimated that': 35002,
#  'estimated that more': 20869,
#  'that more than': 69495,
#  'more than million': 44885,
#  'than million households': 69015,
#  'million households co': 43953,
#  'households co yimhamidbe': 31003,
#  'rt gop as': 60230,
#  'gop as joe': 27073,
#  'as joe biden': 6106,
#  'joe biden travels': 37342,
#  'biden travels to': 9361,
#  'travels to oregon': 78413,
#  'to oregon today': 76641,
#  'oregon today its': 51920,
#  'today its citizens': 77593,
#  'its citizens face': 36823,
#  'citizens face this': 13517,
#  'face this reality': 21753,
#  'this reality bidenflation': 74556,
#  'reality bidenflation is': 57360,
#  'bidenflation is costing': 9369,
#  'is costing the': 34928,
#  'costing the average': 15397,
#  'the average oregon': 69911,
#  'average oregon family': 7135,
#  'oregon family an': 51918,
#  'family an extra': 21980,
#  'steam train drawing': 66644,
#  'train drawing available': 78295,
#  'drawing available on': 19224,
#  'masks magnets train': 42869,
#  'magnets train co': 41604,
#  'train co nfhphzd': 78294,
#  'there are fears': 73469,
#  'are fears that': 5348,
#  'fears that namibia': 22340,
#  'that namibia annual': 69501,
#  'namibia annual inflation': 46124,
#  'annual inflation could': 4628,
#  'inflation could reach': 33907,
#  'could reach high': 15470,
#  'reach high of': 57131,
#  'high of this': 30105,
#  'of this year': 49969,
#  'this year unless': 74714,
#  'year unless there': 86143,
#  'unless there are': 79675,
#  'there are significant': 73479,
#  'are significant de': 5572,
#  'significant de co': 64563,
#  'de co twsxzzkil': 16877,
#  'rt mazzucatom women': 60855,
#  'mazzucatom women economists': 43096,
#  'women economists supporting': 85245,
#  'economists supporting women': 19905,
#  'supporting women economists': 67733,
#  'women economists my': 85244,
#  'economists my buddies': 19903,
#  'my buddies kateraworth': 45799,
#  'buddies kateraworth and': 10860,
#  'kateraworth and stephaniekelton': 38033,
#  'and stephaniekelton co': 4151,
#  'stephaniekelton co evcjaevi': 66677,
#  'measures taken to': 43359,
#  'taken to curb': 68166,
#  'to curb the': 75822,
#  'curb the spread': 16264,
#  'the spread of': 72454,
#  'spread of covid': 66124,
#  'of covid contributed': 48803,
#  'covid contributed to': 15700,
#  'contributed to social': 15215,
#  'to social fallout': 77039,
#  'social fallout in': 65352,
#  'fallout in families': 21943,
#  'in families and': 32429,
#  'families and negatively': 21964,
#  'and negatively impacted': 3898,
#  'negatively impacted the': 46561,
#  'impacted the co': 32013,
#  'the co sxgysqdqr': 70279,
#  'rt bootstrapcook your': 59674,
#  'bootstrapcook your regular': 10134,
#  'your regular reminder': 87393,
#  'regular reminder that': 57817,
#  'reminder that yes': 57993,
#  'that yes while': 69772,
#  'yes while write': 86299,
#  'while write ultra': 83636,
#  'write ultra cheap': 85863,
#  'ultra cheap recipes': 79393,
#  'cheap recipes in': 13137,
#  'recipes in order': 57600,
#  'in order to': 32839,
#  'order to try': 51895,
#  'to try to': 77356,
#  'try to help': 78784,
#  'to help people': 76255,
#  'help people survive': 29722,
#  'people survive under': 53762,
#  'survive under the': 67852,
#  'under the callou': 79476,
#  'vijayanpinarayi candoalljai cpimspeak': 80909,
#  'candoalljai cpimspeak salute': 12257,
#  'cpimspeak salute to': 15789,
#  'salute to this': 62605,
#  'to this brave': 77319,
#  'this brave lady': 74212,
#  'brave lady vrunda': 10413,
#  'lady vrunda karat': 38848,
#  'vrunda karat who': 81146,
#  'karat who was': 37990,
#  'who was only': 83844,
#  'was only present': 81711,
#  'only present on': 51533,
#  'present on ground': 55411,
#  'on ground yes': 50709,
#  'ground yes co': 27705,
#  'yes co jobdszupbc': 86273,
#  'rt wbznightside tonight': 61960,
#  'wbznightside tonight thurs': 82054,
#  'tonight thurs on': 77828,
#  'thurs on nightside': 74954,
#  'on nightside bill': 50843,
#  'nightside bill in': 47296,
#  'bill in rhode': 9479,
#  'in rhode island': 32949,
#  'rhode island would': 58651,
#  'island would fine': 35963,
#  'would fine amp': 85758,
#  'fine amp tax': 22823,
#  'amp tax residents': 2761,
#  'tax residents refusing': 68402,
#  'residents refusing covid': 58280,
#  'refusing covid shot': 57755,
#  'coreytaylorrock on cmft': 15314,
#  'on cmft need': 50587,
#  'cmft need two': 13856,
#  'need two more': 46505,
#  'two more guys': 79084,
#  'more guys for': 44758,
#  'guys for the': 27935,
#  'for the ultimate': 24243,
#  'the ultimate video': 72750,
#  'ultimate video just': 79390,
#  'video just suggestion': 80871,
#  'just suggestion charliesheen': 37865,
#  'suggestion charliesheen and': 67493,
#  'charliesheen and slash': 13079,
#  'rt justin_willsonn marvin': 60573,
#  'justin_willsonn marvin chart': 37921,
#  'marvin chart about': 42541,
#  'chart about to': 13083,
#  'about to go': 360,
#  'to go parabolic': 76151,
#  'go parabolic as': 26521,
#  'parabolic as btok': 53063,
#  'as btok campaign': 6006,
#  'btok campaign comes': 10829,
#  'campaign comes live': 11930,
#  'comes live april': 14468,
#  'live april rd': 40499,
#  'april rd price': 5118,
#  'rd price still': 57019,
#  'price still at': 55575,
#  'still at discount': 66746,
#  'at discount on': 6567,
#  'discount on both': 18081,
#  'on both chains': 50565,
#  'rt ashleymarvin_ marvininu': 59546,
#  'ashleymarvin_ marvininu is': 6324,
#  'marvininu is set': 42767,
#  'is set to': 35571,
#  'set to conquer': 63770,
#  'to conquer the': 75783,
#  'conquer the memecoin': 15010,
#  'the memecoin universe': 71507,
#  'memecoin universe with': 43556,
#  'universe with amazing': 79626,
#  'with amazing utilities': 84606,
#  'amazing utilities get': 2349,
#  'utilities get ur': 80412,
#  'get ur ticket': 26137,
#  'ur ticket to': 80059,
#  'ticket to mars': 74977,
#  'to mars by': 76515,
#  'mars by bagging': 42479,
#  'by bagging as': 11507,
#  'bagging as much': 7474,
#  'as much mar': 6136,
#  'namibia has slipped': 46125,
#  'has slipped seven': 28688,
#  'slipped seven places': 64954,
#  'seven places on': 63804,
#  'places on highly': 54315,
#  'on highly regarded': 50728,
#  'highly regarded global': 30221,
#  'regarded global survey': 57758,
#  'global survey measuring': 26440,
#  'survey measuring investment': 67846,
#  'measuring investment attractiveness': 43361,
#  'investment attractiveness of': 34567,
#  'attractiveness of mining': 6980,
#  'of mining co': 49295,
#  'mining co yglwxsqfc': 44074,
#  'philinv nzedaus the': 54101,
#  'nzedaus the coherent': 48438,
#  'the coherent argument': 70302,
#  'coherent argument against': 14248,
#  'argument against it': 5803,
#  'against it is': 1254,
#  'it is fear': 36357,
#  'is fear by': 35022,
#  'fear by political': 22327,
#  'by political partys': 11652,
#  'political partys lol': 54832,
#  'rt johnnyakzam it': 60535,
#  'johnnyakzam it time': 37396,
#  'it time for': 36663,
#  'time for members': 75062,
#  'for members of': 23896,
#  'members of the': 43524,
#  'of the so': 49855,
#  'the so called': 72424,
#  'so called progressive': 65127,
#  'called progressive caucus': 11861,
#  'progressive caucus to': 55943,
#  'caucus to tweet': 12613,
#  'to tweet less': 77362,
#  'tweet less and': 78944,
#  'less and do': 39696,
#  'and do more': 3354,
#  'do more to': 18377,
#  'more to leverage': 44919,
#  'to leverage their': 76441,
#  'leverage their voting': 39883,
#  'their voting bloc': 73255,
#  'voting bloc in': 81130,
#  'bloc in congr': 9850,
#  'totally agree aging': 78065,
#  'agree aging is': 1351,
#  'aging is the': 1325,
#  'is the natural': 35741,
#  'the natural order': 71688,
#  'natural order of': 46297,
#  'order of life': 51887,
#  'of life and': 49202,
#  'life and we': 40005,
#  'and we should': 4399,
#  'we should seek': 82417,
#  'should seek to': 64340,
#  'seek to alter': 63440,
#  'to alter it': 75368,
#  'alter it see': 2144,
#  'it see beauty': 36583,
#  'see beauty and': 63323,
#  'beauty and wisdom': 8308,
#  'and wisdom in': 4443,
#  'wisdom in age': 84536,
#  'in age co': 32149,
#  'age co fmhxlcoa': 1293,
#  'crypto whale transfer': 16141,
#  'whale transfer alert': 82998,
#  'transfer alert btc': 78330,
#  'alert btc were': 1634,
#  'btc were transferred': 10817,
#  'were transferred from': 82935,
#  'transferred from binance': 78338,
#  'from binance to': 24971,
#  'binance to unknown': 9568,
#  'to unknown address': 77385,
#  'unknown address wqqcoscz': 79658,
#  'address wqqcoscz co': 824,
#  'wqqcoscz co pblrbrsr': 85848,
#  'this is always': 74364,
#  'is always really': 34753,
#  'always really great': 2210,
#  'really great to': 57411,
#  'great to hear': 27522,
#  'to hear about': 76232,
#  'hear about the': 29568,
#  'about the conveniencestore': 308,
#  'the conveniencestore segment': 70341,
#  'conveniencestore segment look': 15248,
#  'segment look how': 63518,
#  'look how far': 40988,
#  'how far this': 31087,
#  'far this industry': 22122,
#  'this industry how': 74357,
#  'industry how come': 33828,
#  'how come co': 31059,
#  'come co rzzepsqa': 14408,
#  'finance minister nsitharaman': 22737,
#  'minister nsitharaman has': 44093,
#  'nsitharaman has said': 48324,
#  'has said that': 28680,
#  'said that there': 62509,
#  'that there is': 69658,
#  'there is an': 73514,
#  'is an urgent': 34782,
#  'an urgent need': 3047,
#  'urgent need for': 80080,
#  'need for coordinated': 46441,
#  'for coordinated action': 23629,
#  'coordinated action across': 15296,
#  'action across countries': 625,
#  'across countries to': 589,
#  'countries to en': 15530,
#  'to en co': 75967,
#  'en co oydgslxfvv': 20423,
#  'peterschiff it so': 54009,
#  'it so interesting': 36616,
#  'so interesting that': 65197,
#  'interesting that you': 34306,
#  'that you mention': 69782,
#  'you mention because': 86833,
#  'mention because on': 43616,
#  'because on the': 8368,
#  'on the chart': 50992,
#  'the chart of': 70211,
#  'chart of oil': 13103,
#  'of oil on': 49378,
#  'oil on log': 50338,
#  'on log scale': 50788,
#  'log scale the': 40786,
#  'scale the upper': 62991,
#  'the upper end': 72773,
#  'upper end of': 80023,
#  'end of th': 20467,
#  'of th co': 49653,
#  'th co nzutmct': 68903,
#  'rt rheensister have': 61359,
#  'rheensister have no': 58650,
#  'have no sympathy': 29030,
#  'no sympathy or': 47520,
#  'sympathy or time': 67966,
#  'or time for': 51851,
#  'time for the': 75068,
#  'for the little': 24187,
#  'the little bitches': 71374,
#  'little bitches banging': 40470,
#  'bitches banging on': 9634,
#  'banging on about': 7567,
#  'on about the': 50494,
#  'about the purebloods': 333,
#  'the purebloods getting': 72107,
#  'purebloods getting access': 56351,
#  'getting access to': 26182,
#  'access to anywhere': 481,
#  'to anywhere we': 75394,
#  'anywhere we bloody': 4914,
#  ...}

# %%
df = pd.DataFrame(trigram_vectorizer.vocabulary_.items(),columns=['Vocabulary','Frequency'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87752 entries, 0 to 87751
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Vocabulary  87752 non-null  object
#  1   Frequency   87752 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df = df.sort_values(by='Frequency',ascending=False)

# %%
df.head(20)
# Out:
#                        Vocabulary  Frequency
# 61523           𝘄𝗼𝗿𝗹𝗱 𝗵𝗮𝘀 𝗰𝗵𝗮𝗻𝗴𝗲𝗱      87751
# 61521             𝘄𝗵𝗶𝗰𝗵 𝘁𝗵𝗲 𝘄𝗼𝗿𝗹𝗱      87750
# 61519               𝘄𝗮𝘆𝘀 𝗶𝗻 𝘄𝗵𝗶𝗰𝗵      87749
# 61522               𝘁𝗵𝗲 𝘄𝗼𝗿𝗹𝗱 𝗵𝗮𝘀      87748
# 37730                𝘁𝗵𝗲 𝗠𝗼𝗻𝘁𝗵 𝗼𝗳      87747
# 39394  𝗿𝗲𝗮𝗱𝘆 mm_footballclub mufc      87746
# 37735                𝗼𝘂𝘁 𝗻𝗼𝘄 grab      87745
# 37732              𝗼𝗳 𝗙𝗲𝗯𝗿𝘂𝗮𝗿𝘆 𝗶𝘀      87744
# 37736               𝗻𝗼𝘄 grab your      87743
# 37734                  𝗶𝘀 𝗼𝘂𝘁 𝗻𝗼𝘄      87742
# 61520                𝗶𝗻 𝘄𝗵𝗶𝗰𝗵 𝘁𝗵𝗲      87741
# 37729               𝗳𝗼𝗿 𝘁𝗵𝗲 𝗠𝗼𝗻𝘁𝗵      87740
# 37726           𝗧𝗵𝗲 𝗛𝗶𝗴𝗵𝗹𝗮𝗻𝗱 𝗖𝗼𝗽𝘀      87739
# 61517             𝗦𝗵𝗶𝗳𝘁 𝗙𝗶𝘃𝗲 𝘄𝗮𝘆𝘀      87738
# 37731           𝗠𝗼𝗻𝘁𝗵 𝗼𝗳 𝗙𝗲𝗯𝗿𝘂𝗮𝗿𝘆      87737
# 37727           𝗛𝗶𝗴𝗵𝗹𝗮𝗻𝗱 𝗖𝗼𝗽𝘀 𝗳𝗼𝗿      87736
# 61516           𝗚𝗹𝗼𝗯𝗮𝗹 𝗦𝗵𝗶𝗳𝘁 𝗙𝗶𝘃𝗲      87735
# 61518                𝗙𝗶𝘃𝗲 𝘄𝗮𝘆𝘀 𝗶𝗻      87734
# 37733             𝗙𝗲𝗯𝗿𝘂𝗮𝗿𝘆 𝗶𝘀 𝗼𝘂𝘁      87733
# 37728                𝗖𝗼𝗽𝘀 𝗳𝗼𝗿 𝘁𝗵𝗲      87732

# %%
df.tail(20)
# Out:
#                                           Vocabulary  Frequency
# 87511                       _idontcomply_ exactly my         19
# 25978                  _fisherofmen_ piersmorgan who         18
# 21743                             _fels just because         17
# 2101                 _fathima_usmaan mr bcnagesh_bjp         16
# 84726                     _f_r_o_t_o bayaann_ follow         15
# 49672              _denisepaul lizzydobres sarmila_v         14
# 65945                _deepphilosophy deep philosophy         13
# 48011                            _crymiariver we don         12
# 65413                           _cingraham it always         11
# 21997                        _cingraham confused how         10
# 66769                        _borutoking looking for          9
# 67615                   _borutoking elonmusk billymk          8
# 19628             _borutoking alex_dreyfus marvininu          7
# 22796                              _are_ possible if          6
# 61100                     _anti_hypocrite jrntr fans          5
# 32848                         _africanunion don miss          4
# 72882  __h__e__a__c__ robertbradleyj tpostmillennial          3
# 82351                         __anncheese night gain          2
# 67247                        ____sj follow aitcrupak          1
# 4853                             ____news just keeps          0

# %%
X_train_trigram = trigram_vectorizer.transform(X_train.values)

# %% [markdown]
# Trigram Tf-Idf

# %%
trigram_tf_idf_transformer = TfidfTransformer()
trigram_tf_idf_transformer.fit(X_train_trigram)
X_train_trigram_tf_idf = trigram_tf_idf_transformer.transform(X_train_trigram)

# %% [markdown]
# SGD Classifier

# %%
def train_and_show_scores(X: csr_matrix, y: np.array, title: str) -> None:
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, test_size=0.75, stratify=y
    )

    clf = SGDClassifier()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    valid_score = clf.score(X_valid, y_valid)
    print(f'{title}\nTrain score: {round(train_score, 2)} ; Validation score: {round(valid_score, 2)}\n')

# %%
train_and_show_scores(X_train_trigram, y_train.values, 'Trigram Counts')
train_and_show_scores(X_train_trigram_tf_idf, y_train.values, 'Trigram Tf-Idf')
# Out:
# Trigram Counts
# Train score: 1.0 ; Validation score: 0.72
#
# Trigram Tf-Idf
# Train score: 1.0 ; Validation score: 0.72

# %% [markdown]
# **Project:** Data Minining Project for  X company

# %% [markdown]
# The CRISP-DM Framework
#
#
# The CRISP-DM methodology provides a structured approach to planning a data mining project. It is a robust and well-proven methodology.
# * Business understanding (BU): Determine Business Objectives, Assess Situation, Determine Data Mining Goals, Produce Project Plan
#
# * Data understanding (DU): Collect Initial Data, Describe Data, Explore Data, Verify Data Quality
#
# * Data preparation (DP): Select Data, Clean Data, Construct Data, Integrate Data
#
# * Modeling (M): Select modeling technique, Generate Test Design, Build Model, Assess Model
# *  Evaluation (E): Evaluate Results, Review Process, Determine Next Steps
# *  Deployment (D): Plan Deployment, Plan Monitoring and Maintenance, Produce Final Report, Review Project
#
#
# References:
#
# [What is the CRISP-DM methodology?](https://www.sv-europe.com/crisp-dm-methodology/)
#
# [Introduction to CRISP DM Framework for Data Science and Machine Learning](https://www.linkedin.com/pulse/chapter-1-introduction-crisp-dm-framework-data-science-anshul-roy/)

# %% [markdown]
# **Data Set**
# ### The data is for company X which is trying to control attrition.
# ### There are two sets of data: "Existing employees" and "Employees who have left". The following attributes are available for every employee.
#
#
# *   Satisfaction Level
#
# *   Last evaluation
#
# *   Number of projects
#
# *   Average monthly hours
#
# *   Time spent at the company
# *   Whether they have had a work accident
#
#
# *  Whether they have had a promotion in the last 5 years
#
#
# *   Departments (column sales)
#
#
# *   Salary
#
#
# *  Whether the employee has left

# %% [markdown]
# **Your Role**
#
#
# *   As data science team member X company asked you to answer this two questions.
# *  What type of employees is leaving?
#
# *   Determine which employees are prone to leave next.

# %% [markdown]
# Business Understanding
#
# ---
#
# This step mostly focuses on understanding the Business in all the different aspects. It follows the below different steps.
#
#
#
#
# * Identify the goal and frame the business problem.
# * Prepare Analytical Goal i.e. what type of performance metric and loss function to use
# * Gather information on resource, constraints, assumptions, risks etc
# * Gather information on resource, constraints, assumptions, risks etc
# *   Prepare Work Flow Chart

# %% [markdown]
# ### Write the main objectives of this project in your words?
# minimum of 100 characters

# %%
main_objectives ='''The main objective of this project is to identify the attributes or underlying factors that lead to an employee leaving the organization and identify what type of employees are departing the organization.

'''

# %%
assert len(main_objectives) > 100 
### BEGIN HIDDEN TESTS
assert len(main_objectives) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### Outline the different data analysis steps you will follow to carry out the project

# %%
dm_outline = '''The different analysis steps I will carry out are as follows. I intend to:
1.check for incomplete data inputs
2.check for outlier data inputs that might diverge the consistency of the  entire data
3.separate employees that left the organization and visualize the data to identify what attributes they highly share in common
4.separate employees that are still in the organization and visualize the data to identify what attributes they highly share in common
5.identify which attributes have the highest impact on the status of an employee
6.find out if I can represent every attribute in a quantitative way
'''

# %%
assert len(dm_outline) > 100 
### BEGIN HIDDEN TESTS
assert len(dm_outline) > 70 
### END HIDDEN TESTS

# %% [markdown]
# ### What metrics will you use to measure the performance of your data analysis model?
# Write the equations of the metrics here

# %% [markdown]
# e.g. Precision = $\frac{TP}{(TP + FP)}$

# %% [markdown]
# Why do you choose these metrics? minimum of 100 characters

# %%
why_metrics = '''I would know if my data analysis work is a success by comparing my trained model weights to the analysis of the attributes. During the analysis phase, the attributes that highly impact the employee status will be identified. These attributes will have to possess high weights in the trained model.
I can also measure the success by evaluating the performance metrics of my model on the test data. A high value will indicate success.
'''

# %%
assert len(why_metrics) > 100 
### BEGIN HIDDEN TESTS
assert len(why_metrics) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### How would you know if your data analysis work is a success or not?
# minimum of 100 characters

# %%
how_success = '''
'''

# %%
assert len(how_success) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ## What kind of challenges do you expect in your analysis?
# List at least 3 challenges

# %%
challenge_text = '''The challenges that expect are:
1.incomplete data
2.invalid data (data with invalid inputs)
3.outlier data (data that is out of the ordinary for an employee to leave or stay at the organization)
4.attributes with less or no effect on the status of the employee
5.none of the attributes being determinant to impact the employees status significantl
'''

# %%
assert len(challenge_text) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# <h2>Using the processed twitter data from yesterday's challenge</h2>.
#
#
# - Form a new data frame (named `cleanTweet`), containing columns $\textbf{clean-text}$ and $\textbf{polarity}$.
#
# - Write a function `text_category` that takes a value `p` and returns, depending on the value of p, a string `'positive'`, `'negative'` or `'neutral'`.
#
# - Apply this function (`text_category`) on the $\textbf{polarity}$ column of `cleanTweet` in 1 above to form a new column called $\textbf{score}$ in `cleanTweet`.
#
# - Visualize The $\textbf{score}$ column using piechart and barchart
#
# <h5>Now we want to build a classification model on the clean tweet following the steps below:</h5>
#
# * Remove rows from `cleanTweet` where $\textbf{polarity}$ $= 0$ (i.e where $\textbf{score}$ = Neutral) and reset the frame index.
# * Construct a column $\textbf{scoremap}$ Use the mapping {'positive':1, 'negative':0} on the $\textbf{score}$ column
# * Create feature and target variables `(X,y)` from $\textbf{clean-text}$ and $\textbf{scoremap}$ columns respectively.
# * Use `train_test_split` function to construct `(X_train, y_train)` and `(X_test, y_test)` from `(X,y)`
#
# * Build an `SGDClassifier` model from the vectorize train text data. Use `CountVectorizer()` with a $\textit{trigram}$ parameter.
#
# * Evaluate your model on the test data.

# %%
import pandas as pd
tweets = pd.read_csv('./cleaned_fintech_data.csv')
tweets.head()
# Out:
#    Unnamed: 0                      created_at  \
# 0         0.0  Thu Jun 17 06:26:34 +0000 2021
# 1         1.0  Thu Jun 17 06:26:37 +0000 2021
# 2         2.0  Thu Jun 17 06:26:42 +0000 2021
# 3         3.0  Thu Jun 17 06:26:44 +0000 2021
# 4         4.0  Thu Jun 17 06:26:47 +0000 2021
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  \
# 0  Giving forth life is becoming a burden in Keny...
# 1  Teenmaar - 26cr\nPanja - 32.5cr\nGabbarsingh -...
# 2  Rei chintu 2013 lo Vachina Ad Nizam ne 2018 lo...
# 3  Today is World Day to Combat #Desertification ...
# 4  Hearing #GregHunt say he's confident vaccines ...
#
# ...

# %%
clean_tweet = pd.DataFrame(columns=['clean_text','polarity'])

clean_tweet['clean_text'] =  tweets['clean_text'].to_list()
clean_tweet['polarity'] =  tweets['polarity'].to_list()

# %%
clean_tweet.dropna()
clean_tweet.drop(clean_tweet.loc[clean_tweet['polarity']=="polarity"].index, inplace=True)
clean_tweet['polarity'] = pd.to_numeric(clean_tweet['polarity'])
clean_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5620 entries, 0 to 5620
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   clean_text  5616 non-null   object
#  1   polarity    5620 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 131.7+ KB

# %%
def text_category(p:float)->str:
    if(p > 0):
        return "positive"
    elif(p < 0):
        return "negative"
    else:
        return "neutral"

# %%
clean_tweet['score'] = clean_tweet.polarity.apply(text_category)

clean_tweet.head()
# Out:
#                                           clean_text  polarity     score
# 0  Giving forth life becoming burden Kenya This m...  0.319444  positive
# 1  Teenmaar crPanja crGabbarsingh cr Khaleja Kuda...  0.000000   neutral
# 2  Rei chintu lo Vachina Ad Nizam ne lo kottaru f...  0.000000   neutral
# 3  Today World Day Combat Restoring degraded land...  0.250000  positive
# 4  Hearing say 's confident vaccines delivered li...  0.500000  positive

# %%
clean_tweet['score'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
clean_tweet['score'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='score'>

# %%
clean_tweet.drop(clean_tweet.loc[clean_tweet['score']=="neutral"].index, inplace=True)
clean_tweet.reset_index(drop=True, inplace=True)
clean_tweet
# Out:
#                                              clean_text  polarity     score
# 0     Giving forth life becoming burden Kenya This m...  0.319444  positive
# 1     Today World Day Combat Restoring degraded land...  0.250000  positive
# 2     Hearing say 's confident vaccines delivered li...  0.500000  positive
# 3     Today World Day Combat Restoring degraded land...  0.250000  positive
# 4     Austria `` right '' grid tariffs regulatory re...  0.285714  positive
# ...                                                 ...       ...       ...
# 3481  In latest episode podcast Unilevers Peter Ter ...  0.279167  positive
# 3482  Lambie voted AGAINST Medivac Carbon tax protec...  0.136364  positive
# 3483  Idhi bathuku Most Day1 Records In Nizam Non BB...  0.500000  positive
# 3484  welkin moon giveaway bc finally money -u got t...  0.154167  positive
# 3485  This first time I 've seen Government media le...  0.130000  positive
#
# [3486 rows x 3 columns]

# %%
def scoremap_category(score:str)->int:
    if(score == "positive"):
        return 1
    else:
        return 0

# %%
clean_tweet['scoremap'] = clean_tweet.score.apply(scoremap_category)
clean_tweet
# Out:
#                                              clean_text  polarity     score  \
# 0     Giving forth life becoming burden Kenya This m...  0.319444  positive
# 1     Today World Day Combat Restoring degraded land...  0.250000  positive
# 2     Hearing say 's confident vaccines delivered li...  0.500000  positive
# 3     Today World Day Combat Restoring degraded land...  0.250000  positive
# 4     Austria `` right '' grid tariffs regulatory re...  0.285714  positive
# ...                                                 ...       ...       ...
# 3481  In latest episode podcast Unilevers Peter Ter ...  0.279167  positive
# 3482  Lambie voted AGAINST Medivac Carbon tax protec...  0.136364  positive
# 3483  Idhi bathuku Most Day1 Records In Nizam Non BB...  0.500000  positive
# 3484  welkin moon giveaway bc finally money -u got t...  0.154167  positive
# 3485  This first time I 've seen Government media le...  0.130000  positive
#
#       scoremap
# 0            1
# 1            1
# ...

# %%
X = clean_tweet['clean_text'].values
Y = clean_tweet['scoremap'].values

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from scipy.sparse import csr_matrix
import numpy as np

# %%
trigram_vectorizer = CountVectorizer(ngram_range=(3, 3))
trigram_vectorizer.fit(X)
# Out:
# CountVectorizer(ngram_range=(3, 3))

# %%
X_train_trigram = trigram_vectorizer.transform(X)

# %%
def train_and_show_scores(X: csr_matrix, y: np.array, title: str) -> None:
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, train_size=0.75, stratify=y
    )

    clf = SGDClassifier()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    print(f'{title}\nTrain score: {round(train_score, 2)} ; test score: {round(test_score, 2)}\n')

# %%
train_and_show_scores(X_train_trigram, Y, 'Trigram Counts')
# Out:
# Trigram Counts
# Train score: 1.0 ; test score: 0.99
